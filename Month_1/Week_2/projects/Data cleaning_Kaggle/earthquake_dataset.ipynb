# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# %% [markdown]
# # Load The Data

# %%
file_path = './database.csv'
earthquakes = pd.read_csv(file_path,index_col='Date',parse_dates=True)
earthquakes.head(40)
# Out:
#                 Time  Latitude  Longitude        Type  Depth  Depth Error  \
# Date
# 01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
# 01/10/1965  13:36:32   -13.405    166.629  Earthquake   35.0          NaN
# 01/12/1965  13:32:25    27.357     87.867  Earthquake   20.0          NaN
# 01/15/1965  23:17:42   -13.309    166.212  Earthquake   35.0          NaN
# 01/16/1965  11:32:37   -56.452    -27.043  Earthquake   95.0          NaN
# 01/17/1965  10:43:17   -24.563    178.487  Earthquake  565.0          NaN
# 01/17/1965  20:57:41    -6.807    108.988  Earthquake  227.9          NaN
# 01/24/1965  00:11:17    -2.608    125.952  Earthquake   20.0          NaN
# ...

# %%
len(earthquakes)
# Out:
# 23412

# %%
# earthquakes.loc[3378,'Date']

earthquakes.dropna()
print(f"lens is = {len(earthquakes.dropna())}")
# Out:
# lens is = 14

# %% [markdown]
# we can't drop all those rows

# %%
clean_data = earthquakes.dropna(axis=1)
clean_data
# Out:
#                 Time  Latitude  Longitude        Type   Depth  Magnitude  \
# Date
# 01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60        6.0
# 01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00        5.8
# 01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00        6.2
# 01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00        5.8
# 01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00        5.8
# ...              ...       ...        ...         ...     ...        ...
# 12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30        5.6
# 12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80        5.5
# 12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00        5.9
# 12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00        6.3
# 12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94        5.5
#
#                       ID  Source Location Source Magnitude Source     Status
# Date
# ...

# %%
len(clean_data.columns)
# Out:
# 11

# %%
len(earthquakes.columns)
# Out:
# 20

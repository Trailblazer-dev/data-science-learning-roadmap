# %% [markdown]
# # Scenario
# You have recently been hired to manage the museums in the City of Los Angeles.
# You will leverage data from the Los Angeles Data Portal that tracks monthly visitors to each museum

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
print('setup complete')
# Out:
# setup complete

# %%
museaum_filepath = './museum_visitors.csv'

# %% [markdown]
# ## Step 1: Load the data

# %%
museum_data = pd.read_csv(museaum_filepath,index_col='Date',parse_dates=True)

# %%
museum_data.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %% [markdown]
# ### Step 2: Review the data
# Use a Python command to print the last 5 rows of the data.

# %%
museum_data.tail()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2018-07-01        23136              4191                     2620
# 2018-08-01        20815              4866                     2409
# 2018-09-01        21020              4956                     2146
# 2018-10-01        19280              4622                     2364
# 2018-11-01        17163              4082                     2385
#
#             America Tropical Interpretive Center
# Date
# 2018-07-01                                  4718
# 2018-08-01                                  3891
# 2018-09-01                                  3180
# 2018-10-01                                  3775
# 2018-11-01                                  4562

# %%
plt.figure(figsize=(12,6))
plt.title('Los Angeles Museum Visitors')
plt.ylabel('Number of visitors')
sns.lineplot(data = museum_data)
# Out:
# <Axes: title={'center': 'Los Angeles Museum Visitors'}, xlabel='Date', ylabel='Number of visitors'>

# %% [markdown]
# ### How many visitors did the Chinese American Museum  receive in July 2018?___

# %% [markdown]
# visitors = '2620'

# %% [markdown]
# ### In October 2018, how many more visitors did Avila Adobe receive than the Firehouse Museum?____

# %% [markdown]
# answer = 14,658

# %% [markdown]
# ## Step 3: Convince the museum board
# The Firehouse Museum claims they ran an event in 2014 that brought an incredible number of visitors, and that they should get extra budget to run a similar event again. The other museums think these types of events aren't that important, and budgets should be split purely based on recent visitors on an average day.
#
# To show the museum board how the event compared to regular traffic at each museum, create a line chart that shows how the number of visitors to each museum

# %%
museum_data.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
list(museum_data.columns)
# Out:
# ['Avila Adobe',
#  'Firehouse Museum',
#  'Chinese American Museum',
#  'America Tropical Interpretive Center']

# %%
plt.figure(figsize=(12,6))
plt.title('Number of visitors in Avila Adobe')
plt.xlabel('Date')
sns.lineplot(data=museum_data['Avila Adobe'],label='Avila Adobe')
# Out:
# <Axes: title={'center': 'Number of visitors in Avila Adobe'}, xlabel='Date', ylabel='Avila Adobe'>

# %%
plt.figure(figsize=(12,6))
plt.title('Number of visitors in Firehouse Museum')

sns.lineplot(data = museum_data['Firehouse Museum'],label = 'Firehouse Museum')
# Out:
# <Axes: title={'center': 'Number of visitors in Firehouse Museum'}, xlabel='Date', ylabel='Firehouse Museum'>

# %%
plt.figure(figsize=(12,6))
plt.title('Number of visitors in Chinese American Museum')

sns.lineplot(data = museum_data['Chinese American Museum'],label ='Chinese American Museum')
# Out:
# <Axes: title={'center': 'Number of visitors in Chinese American Museum'}, xlabel='Date', ylabel='Chinese American Museum'>

# %%
plt.figure(figsize=(12,6))
plt.title('Number of visitors in America Tropical Interpretive Center')

sns.lineplot(data = museum_data['America Tropical Interpretive Center'],label = 'America Tropical Interpretive Center')
# Out:
# <Axes: title={'center': 'Number of visitors in America Tropical Interpretive Center'}, xlabel='Date', ylabel='America Tropical Interpretive Center'>

# %% [markdown]
# ## Step 4: Assess seasonality
#
# When meeting with the employees at Avila Adobe, you hear that one major pain point is that the number of museum visitors varies greatly with the seasons, with low seasons (when the employees are perfectly staffed and happy) and also high seasons (when the employees are understaffed and stressed). You realize that if you can predict these high and low seasons, you can plan ahead to hire some additional seasonal employees to help out with the extra work.

# %% [markdown]
# ### Part A
#
# Create a line chart that shows how the number of visitors to Avila Adobe has evolved over time. (If your code returns an error, the first thing that you should check is that you've spelled the name of the column correctly! You must write the name of the column exactly as it appears in the dataset.)

# %%
plt.figure(figsize=(12,6))
plt.title('Number of visitors in Avila Adobe')
plt.xlabel('Date')
sns.lineplot(data=museum_data['Avila Adobe'],label='Avila Adobe')
# Out:
# <Axes: title={'center': 'Number of visitors in Avila Adobe'}, xlabel='Date', ylabel='Avila Adobe'>

# %% [markdown]
# ### Part B
#
# Does Avila Adobe get more visitors:
#
#     in September-February (in LA, the fall and winter months), or
#     in March-August (in LA, the spring and summer)?
#
# Using this information, when should the museum staff additional seasonal employees?
